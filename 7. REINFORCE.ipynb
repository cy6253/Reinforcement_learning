# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma         = 0.98

class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.data = []
        
        self.fc1 = nn.Linear(4, 128)
        self.fc2 = nn.Linear(128, 2)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.softmax(self.fc2(x), dim=0)
        return x
      
    def put_data(self, item):
        self.data.append(item)
        
    def train_net(self):
        R = 0
        self.optimizer.zero_grad()
        for r, prob in self.data[::-1]:
            R = r + gamma * R
            loss = -torch.log(prob) * R
            loss.backward()
        self.optimizer.step()
        self.data = []

def main():
    env = gym.make('CartPole-v1')
    pi = Policy()
    score = 0.0
    print_interval = 20
    
    for n_epi in range(10000):
        s = env.reset()
        done = False
        
        while not done: # CartPole-v1 forced to terminates at 500 step.
            prob = pi(torch.from_numpy(s).float())
            m = Categorical(prob)
            a = m.sample()
            s_prime, r, done, info = env.step(a.item())
            pi.put_data((r,prob[a]))
            s = s_prime
            score += r
            
        pi.train_net()
        
        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {}".format(n_epi, score/print_interval))
            score = 0.0
    env.close()
    
if __name__ == '__main__':
    main()
# Out:
# /usr/local/lib/python3.8/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.8/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# # of episode :20, avg score : 26.5
# # of episode :40, avg score : 18.75
# # of episode :60, avg score : 19.75
# # of episode :80, avg score : 20.5
# # of episode :100, avg score : 20.7
# # of episode :120, avg score : 22.2
# # of episode :140, avg score : 21.45
# # of episode :160, avg score : 24.8
# # of episode :180, avg score : 23.4
# # of episode :200, avg score : 24.35
# # of episode :220, avg score : 33.4
# # of episode :240, avg score : 33.3
# # of episode :260, avg score : 26.1
# # of episode :280, avg score : 31.8
# # of episode :300, avg score : 30.2
# # of episode :320, avg score : 35.55
# # of episode :340, avg score : 23.75
# # of episode :360, avg score : 27.7
# # of episode :380, avg score : 32.95
# # of episode :400, avg score : 32.3
# # of episode :420, avg score : 41.0
# # of episode :440, avg score : 34.6
# # of episode :460, avg score : 41.05
# # of episode :480, avg score : 43.9
# # of episode :500, avg score : 40.85
# # of episode :520, avg score : 42.55
# # of episode :540, avg score : 43.15
# # of episode :560, avg score : 40.15
# # of episode :580, avg score : 57.8
# # of episode :600, avg score : 44.05
# # of episode :620, avg score : 50.15
# # of episode :640, avg score : 41.55
# # of episode :660, avg score : 50.5
# # of episode :680, avg score : 77.1
# # of episode :700, avg score : 59.5
# # of episode :720, avg score : 72.55
# # of episode :740, avg score : 63.4
# # of episode :760, avg score : 75.65
# # of episode :780, avg score : 73.95
# # of episode :800, avg score : 86.7
# # of episode :820, avg score : 66.8
# # of episode :840, avg score : 75.3
# # of episode :860, avg score : 62.45
# # of episode :880, avg score : 95.7
# # of episode :900, avg score : 91.25
# # of episode :920, avg score : 87.1
# # of episode :940, avg score : 90.0
# # of episode :960, avg score : 118.9
# # of episode :980, avg score : 103.75
# # of episode :1000, avg score : 92.45
# # of episode :1020, avg score : 130.0
# # of episode :1040, avg score : 121.15
# # of episode :1060, avg score : 126.7
# # of episode :1080, avg score : 103.35
# # of episode :1100, avg score : 127.35
# # of episode :1120, avg score : 133.1
# # of episode :1140, avg score : 125.1
# # of episode :1160, avg score : 131.05
# # of episode :1180, avg score : 155.95
# # of episode :1200, avg score : 148.45
# # of episode :1220, avg score : 170.75
# # of episode :1240, avg score : 168.05
# # of episode :1260, avg score : 158.35
# # of episode :1280, avg score : 152.05
# # of episode :1300, avg score : 154.35
# # of episode :1320, avg score : 169.85
# # of episode :1340, avg score : 143.0
# # of episode :1360, avg score : 175.45
# # of episode :1380, avg score : 199.65
# # of episode :1400, avg score : 210.25
# # of episode :1420, avg score : 193.85
# # of episode :1440, avg score : 177.75
# # of episode :1460, avg score : 216.65
# # of episode :1480, avg score : 189.55
# # of episode :1500, avg score : 218.5
# # of episode :1520, avg score : 228.3
# # of episode :1540, avg score : 174.2
# # of episode :1560, avg score : 214.75
# # of episode :1580, avg score : 210.9
# # of episode :1600, avg score : 200.65
# # of episode :1620, avg score : 177.05
# # of episode :1640, avg score : 184.8
# # of episode :1660, avg score : 203.25
# # of episode :1680, avg score : 229.0
# # of episode :1700, avg score : 214.45
# # of episode :1720, avg score : 230.35
# # of episode :1740, avg score : 264.3
# # of episode :1760, avg score : 258.05
# # of episode :1780, avg score : 249.3
# # of episode :1800, avg score : 229.85
# # of episode :1820, avg score : 248.95
# # of episode :1840, avg score : 220.45
# # of episode :1860, avg score : 228.2
# # of episode :1880, avg score : 240.7
# # of episode :1900, avg score : 272.7
# # of episode :1920, avg score : 260.55
# # of episode :1940, avg score : 236.15
# # of episode :1960, avg score : 198.6
# # of episode :1980, avg score : 265.3
# # of episode :2000, avg score : 262.05
# # of episode :2020, avg score : 231.15
# # of episode :2040, avg score : 247.9
# # of episode :2060, avg score : 286.85
# # of episode :2080, avg score : 295.6
# # of episode :2100, avg score : 303.85
# # of episode :2120, avg score : 289.5
# # of episode :2140, avg score : 296.75
# # of episode :2160, avg score : 273.05
# # of episode :2180, avg score : 262.4
# # of episode :2200, avg score : 271.25
# # of episode :2220, avg score : 291.05
# # of episode :2240, avg score : 311.65
# # of episode :2260, avg score : 294.5
# # of episode :2280, avg score : 271.4
# # of episode :2300, avg score : 315.25
# # of episode :2320, avg score : 298.15
# # of episode :2340, avg score : 307.8
# # of episode :2360, avg score : 359.25
# # of episode :2380, avg score : 325.5
# # of episode :2400, avg score : 338.45
# # of episode :2420, avg score : 294.7
# # of episode :2440, avg score : 299.95
# # of episode :2460, avg score : 254.5
# # of episode :2480, avg score : 328.65
# # of episode :2500, avg score : 299.75
# # of episode :2520, avg score : 300.45
# # of episode :2540, avg score : 313.9
# # of episode :2560, avg score : 284.95
# # of episode :2580, avg score : 331.45
# # of episode :2600, avg score : 275.3
# # of episode :2620, avg score : 301.35
# # of episode :2640, avg score : 328.95
# # of episode :2660, avg score : 367.2
# # of episode :2680, avg score : 273.0
# # of episode :2700, avg score : 365.75
# # of episode :2720, avg score : 357.2
# # of episode :2740, avg score : 322.6
# # of episode :2760, avg score : 381.2
# # of episode :2780, avg score : 285.8
# # of episode :2800, avg score : 357.3
# # of episode :2820, avg score : 322.2
# # of episode :2840, avg score : 347.45
# # of episode :2860, avg score : 385.25
# # of episode :2880, avg score : 358.05
# # of episode :2900, avg score : 347.75
# # of episode :2920, avg score : 334.8
# # of episode :2940, avg score : 333.7
# # of episode :2960, avg score : 357.5
# # of episode :2980, avg score : 385.7
# # of episode :3000, avg score : 330.7
# # of episode :3020, avg score : 413.45
# # of episode :3040, avg score : 311.95
# # of episode :3060, avg score : 401.0
# # of episode :3080, avg score : 387.3
# # of episode :3100, avg score : 394.15
# # of episode :3120, avg score : 409.9
# # of episode :3140, avg score : 418.6
# # of episode :3160, avg score : 384.8
# # of episode :3180, avg score : 386.25
# # of episode :3200, avg score : 372.65
# # of episode :3220, avg score : 321.65
# # of episode :3240, avg score : 332.15
# # of episode :3260, avg score : 324.8
# # of episode :3280, avg score : 340.7
# # of episode :3300, avg score : 304.55
# # of episode :3320, avg score : 357.8
# # of episode :3340, avg score : 349.25
# # of episode :3360, avg score : 400.05
# # of episode :3380, avg score : 376.7
# # of episode :3400, avg score : 332.1
# # of episode :3420, avg score : 340.75
# # of episode :3440, avg score : 397.95
# # of episode :3460, avg score : 430.8
# # of episode :3480, avg score : 406.15
# # of episode :3500, avg score : 375.65
# # of episode :3520, avg score : 415.0
# # of episode :3540, avg score : 417.35
# # of episode :3560, avg score : 425.6
# # of episode :3580, avg score : 391.3
# # of episode :3600, avg score : 409.95
# # of episode :3620, avg score : 366.85
# # of episode :3640, avg score : 442.45
# # of episode :3660, avg score : 356.35
# # of episode :3680, avg score : 381.55
# # of episode :3700, avg score : 339.15
# # of episode :3720, avg score : 388.45
# # of episode :3740, avg score : 393.0
# # of episode :3760, avg score : 403.15
# # of episode :3780, avg score : 373.95
# # of episode :3800, avg score : 404.5
# # of episode :3820, avg score : 451.3
# # of episode :3840, avg score : 387.85
# # of episode :3860, avg score : 422.15
# # of episode :3880, avg score : 434.85
# # of episode :3900, avg score : 368.3
# # of episode :3920, avg score : 449.9
# # of episode :3940, avg score : 424.55
# # of episode :3960, avg score : 430.7
# # of episode :3980, avg score : 467.6
# # of episode :4000, avg score : 415.95
# # of episode :4020, avg score : 386.4
# # of episode :4040, avg score : 423.85
# # of episode :4060, avg score : 444.45
# # of episode :4080, avg score : 399.35
# # of episode :4100, avg score : 437.0
# # of episode :4120, avg score : 467.15
# # of episode :4140, avg score : 417.9
# # of episode :4160, avg score : 399.75
# # of episode :4180, avg score : 452.5
# # of episode :4200, avg score : 440.25
# # of episode :4220, avg score : 408.5
# # of episode :4240, avg score : 471.9
# # of episode :4260, avg score : 417.2
# # of episode :4280, avg score : 444.6
# # of episode :4300, avg score : 425.95
# # of episode :4320, avg score : 421.9
# # of episode :4340, avg score : 427.25
# # of episode :4360, avg score : 419.1
# # of episode :4380, avg score : 412.85
# # of episode :4400, avg score : 428.35
# # of episode :4420, avg score : 440.45
# # of episode :4440, avg score : 414.25
# # of episode :4460, avg score : 445.05
# # of episode :4480, avg score : 436.45
# # of episode :4500, avg score : 444.5
# # of episode :4520, avg score : 454.55
# # of episode :4540, avg score : 450.45
# # of episode :4560, avg score : 420.55
# # of episode :4580, avg score : 381.55
# # of episode :4600, avg score : 416.0
# # of episode :4620, avg score : 398.1
# # of episode :4640, avg score : 416.8
# # of episode :4660, avg score : 409.1
# # of episode :4680, avg score : 473.15
# # of episode :4700, avg score : 481.5
# # of episode :4720, avg score : 475.05
# # of episode :4740, avg score : 447.1
# # of episode :4760, avg score : 453.0
# # of episode :4780, avg score : 466.0
# # of episode :4800, avg score : 405.8
# # of episode :4820, avg score : 461.55
# # of episode :4840, avg score : 442.85
# # of episode :4860, avg score : 445.3
# # of episode :4880, avg score : 384.7
# # of episode :4900, avg score : 474.25
# # of episode :4920, avg score : 415.95
# # of episode :4940, avg score : 457.7
# # of episode :4960, avg score : 420.5
# # of episode :4980, avg score : 437.0
# # of episode :5000, avg score : 425.25
# # of episode :5020, avg score : 406.05
# # of episode :5040, avg score : 475.4
# # of episode :5060, avg score : 450.8
# # of episode :5080, avg score : 476.85
# # of episode :5100, avg score : 442.75
# # of episode :5120, avg score : 442.35
# # of episode :5140, avg score : 393.65
# # of episode :5160, avg score : 478.9
# # of episode :5180, avg score : 449.45
# # of episode :5200, avg score : 424.35
# # of episode :5220, avg score : 422.1
# # of episode :5240, avg score : 473.5
# # of episode :5260, avg score : 412.15
# # of episode :5280, avg score : 442.8
# # of episode :5300, avg score : 444.2
# # of episode :5320, avg score : 452.7
# # of episode :5340, avg score : 402.55
# # of episode :5360, avg score : 387.95
# # of episode :5380, avg score : 325.85
# # of episode :5400, avg score : 354.5
# # of episode :5420, avg score : 330.9
# # of episode :5440, avg score : 346.7
# # of episode :5460, avg score : 382.4
# # of episode :5480, avg score : 358.4
# # of episode :5500, avg score : 351.8
# # of episode :5520, avg score : 326.4
# # of episode :5540, avg score : 263.8
# # of episode :5560, avg score : 287.95
# # of episode :5580, avg score : 288.85
# # of episode :5600, avg score : 296.6
# # of episode :5620, avg score : 348.7
# # of episode :5640, avg score : 331.55
# # of episode :5660, avg score : 298.25
# # of episode :5680, avg score : 364.65
# # of episode :5700, avg score : 336.05
# # of episode :5720, avg score : 422.85
# # of episode :5740, avg score : 347.55
# # of episode :5760, avg score : 381.0
# # of episode :5780, avg score : 395.3
# # of episode :5800, avg score : 385.85
# # of episode :5820, avg score : 416.1
# # of episode :5840, avg score : 437.05
# # of episode :5860, avg score : 400.25
# # of episode :5880, avg score : 418.95
# # of episode :5900, avg score : 411.0
# # of episode :5920, avg score : 449.7
# # of episode :5940, avg score : 413.4
# # of episode :5960, avg score : 453.85
# # of episode :5980, avg score : 443.75
# # of episode :6000, avg score : 463.65
# # of episode :6020, avg score : 445.35
# # of episode :6040, avg score : 483.3
# # of episode :6060, avg score : 438.35
# # of episode :6080, avg score : 432.35
# # of episode :6100, avg score : 344.95
# # of episode :6120, avg score : 444.05
# # of episode :6140, avg score : 407.9
# # of episode :6160, avg score : 412.3
# # of episode :6180, avg score : 453.6
# # of episode :6200, avg score : 479.5
# # of episode :6220, avg score : 467.3
# # of episode :6240, avg score : 450.45
# # of episode :6260, avg score : 450.75
# # of episode :6280, avg score : 429.3
# # of episode :6300, avg score : 423.5
# # of episode :6320, avg score : 438.85
# # of episode :6340, avg score : 473.2
# # of episode :6360, avg score : 433.05
# # of episode :6380, avg score : 465.9
# # of episode :6400, avg score : 489.0
# # of episode :6420, avg score : 457.3
# # of episode :6440, avg score : 466.15
# # of episode :6460, avg score : 463.55
# # of episode :6480, avg score : 424.75
# # of episode :6500, avg score : 474.6
# # of episode :6520, avg score : 489.3
# # of episode :6540, avg score : 466.55
# # of episode :6560, avg score : 445.8
# # of episode :6580, avg score : 497.05
# # of episode :6600, avg score : 459.0
# # of episode :6620, avg score : 482.85
# # of episode :6640, avg score : 423.9
# # of episode :6660, avg score : 468.2
# # of episode :6680, avg score : 461.3
# # of episode :6700, avg score : 441.7
# # of episode :6720, avg score : 478.15
# # of episode :6740, avg score : 485.8
# # of episode :6760, avg score : 476.8
# # of episode :6780, avg score : 450.1
# # of episode :6800, avg score : 456.7
# # of episode :6820, avg score : 476.4
# # of episode :6840, avg score : 462.1
# # of episode :6860, avg score : 449.85
# # of episode :6880, avg score : 451.6
# # of episode :6900, avg score : 459.15
# # of episode :6920, avg score : 444.85
# # of episode :6940, avg score : 467.45
# # of episode :6960, avg score : 449.35
# # of episode :6980, avg score : 447.05
# # of episode :7000, avg score : 459.25
# # of episode :7020, avg score : 475.8
# # of episode :7040, avg score : 473.7
# # of episode :7060, avg score : 495.6
# # of episode :7080, avg score : 427.85
# # of episode :7100, avg score : 484.55
# # of episode :7120, avg score : 450.2
# # of episode :7140, avg score : 466.6
# # of episode :7160, avg score : 464.75
# # of episode :7180, avg score : 465.7
# # of episode :7200, avg score : 462.7
# # of episode :7220, avg score : 488.5
# # of episode :7240, avg score : 482.45
# # of episode :7260, avg score : 449.6
# # of episode :7280, avg score : 476.85
# # of episode :7300, avg score : 473.4
# # of episode :7320, avg score : 456.8
# # of episode :7340, avg score : 484.8
# # of episode :7360, avg score : 483.15
# # of episode :7380, avg score : 456.75
# # of episode :7400, avg score : 460.9
# # of episode :7420, avg score : 490.25
# # of episode :7440, avg score : 493.95
# # of episode :7460, avg score : 470.0
# # of episode :7480, avg score : 500.0
# # of episode :7500, avg score : 500.0
# # of episode :7520, avg score : 482.35
# # of episode :7540, avg score : 459.8
# # of episode :7560, avg score : 483.2
# # of episode :7580, avg score : 489.35
# # of episode :7600, avg score : 482.95
# # of episode :7620, avg score : 475.3
# # of episode :7640, avg score : 476.2
# # of episode :7660, avg score : 500.0
# # of episode :7680, avg score : 492.75
# # of episode :7700, avg score : 483.7
# # of episode :7720, avg score : 489.2
# # of episode :7740, avg score : 494.9
# # of episode :7760, avg score : 500.0
# # of episode :7780, avg score : 481.6
# # of episode :7800, avg score : 473.8
# # of episode :7820, avg score : 500.0
# # of episode :7840, avg score : 474.3
# # of episode :7860, avg score : 482.6
# # of episode :7880, avg score : 471.3
# # of episode :7900, avg score : 483.75
# # of episode :7920, avg score : 487.85
# # of episode :7940, avg score : 483.85
# # of episode :7960, avg score : 475.8
# # of episode :7980, avg score : 469.95
# # of episode :8000, avg score : 482.7
# # of episode :8020, avg score : 492.75
# # of episode :8040, avg score : 470.55
# # of episode :8060, avg score : 497.05
# # of episode :8080, avg score : 480.1
# # of episode :8100, avg score : 490.35
# # of episode :8120, avg score : 480.15
# # of episode :8140, avg score : 490.75
# # of episode :8160, avg score : 480.3
# # of episode :8180, avg score : 489.65
# # of episode :8200, avg score : 494.7
# # of episode :8220, avg score : 482.75
# # of episode :8240, avg score : 478.5
# # of episode :8260, avg score : 474.7
# # of episode :8280, avg score : 490.7
